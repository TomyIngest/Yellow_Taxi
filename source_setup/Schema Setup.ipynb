# %%
spark.sql("CREATE catalog if not exists NY_Taxi MANAGED LOCATION 'abfss://unity-catalog-storage@dbstoragertkgqhhy66nu6.dfs.core.windows.net/1290381263006333'")

# %%
spark.sql("create schema if not exists NY_Taxi.Data")
spark.sql("create schema if not exists NY_Taxi.01_Bronze")
spark.sql("create schema if not exists NY_Taxi.02_Silver")
spark.sql("create schema if not exists NY_Taxi.03_Gold")

# %%
spark.sql("show schemas in NY_Taxi").display()

# %%
spark.sql("create volume if not exists NY_Taxi.data.source_files")

# %%
spark.sql("show volumes in NY_Taxi.data").display()

# %%
dbutils.fs.mkdirs('/Volumes/ny_taxi/data/source_files/Taxi_data')
dbutils.fs.mkdirs('/Volumes/ny_taxi/data/source_files/other')

# %%
# removing everything from given location
for item in dbutils.fs.ls("/Volumes/ny_taxi/data/source_files/Taxi_data/"):
    dbutils.fs.rm(item.path, recurse=True)
